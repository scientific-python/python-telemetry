# %% [markdown]
# ```
# OTEL_RESOURCE_ATTRIBUTES="service.name=scipy,service.namespace=scientific-python,deployment.environment=production"
# OTEL_EXPORTER_OTLP_ENDPOINT="https://otlp-gateway-prod-us-west-0.grafana.net/otlp"
# OTEL_EXPORTER_OTLP_HEADERS="Authorization=Basic%20MTI1Mzk2NjpnbGNfZXlKdklqb2lNVFF5TmpVMk9DSXNJbTRpT2lKemRHRmpheTB4TWpVek9UWTJMVzkwWld3dGIyNWliMkZ5WkdsdVp5MTBaWE4wSWl3aWF5STZJakJ3TjNZeWNqWlhOelZWTUdwVk1scDBWREJ1TUc1VFR5SXNJbTBpT25zaWNpSTZJbkJ5YjJRdGRYTXRkMlZ6ZEMwd0luMTk="
# OTEL_EXPORTER_OTLP_PROTOCOL="http/protobuf"
# ```

# %%
from opentelemetry.instrumentation.auto_instrumentation import initialize

from api_tracer import install
from api_tracer.console import setup_console

# Set up which modules should be instrumented
install([
    "scipy.stats._correlation",
    "scipy.stats._distn_infrastructure"
])

# Set up Grafana Cloud logging
initialize()

# Set up Console logging
setup_console()
# Out:
# Overriding of current TracerProvider is not allowed
# {
#     "name": "scipy.stats._distn_infrastructure.get_distribution_names",
#     "context": {
#         "trace_id": "0x52bb86a56b64a40300dd9f584720b9fa",
#         "span_id": "0xf5c505309dbfd888",
#         "trace_state": "[]"
#     },
#     "kind": "SpanKind.INTERNAL",
#     "parent_id": null,
#     "start_time": "2025-05-12T22:18:56.879840Z",
#     "end_time": "2025-05-12T22:18:56.880502Z",
#     "status": {
#         "status_code": "OK"
#     },
#     "attributes": {
#         "num_args": 2,
#         "num_kwargs": 0,
#         "args.0": "[('__name__', 'scipy.stats._continuous_distns'), ('__doc__', None), ('__package__', 'scipy.stats'), ('__loader__', <_frozen_importlib_external.SourceFileLoader object at 0x11a1d9760>), ('__spec__', ModuleSpec(name='scipy.stats._continuous_distns', loader=<_frozen_importlib_external.SourceFileLoader object at 0x11a1d9760>, origin='/Users/guen/repos/guenp/api-tracer/.venv/lib/python3.12/site-packages/scipy/stats/_continuous_distns.py')), ('__file__', '/Users/guen/repos/guenp/api-tracer/.venv/lib/python3.12/site-packages/scipy/stats/_continuous_distns.py'), ('__cached__', '/Users/guen/repos/guenp/api-tracer/.venv/lib/python3.12/site-packages/scipy/stats/__pycache__/_continuous_distns.cpython-312.pyc'), ('__builtins__', {'__name__': 'builtins', '__doc__': \"Built-in functions, types, exceptions, and other objects.\\n\\nThis module provides direct access to all 'built-in'\\nidentifiers of Python; for example, builtins.len is\\nthe full name for the built-in function len().\\n\\nThis module is not normally accessed explicitly by most\\napplications, but can be useful in modules that provide\\nobjects with the same name as a built-in value, but in\\nwhich the built-in of that name is also needed.\", '__package__': '', '__loader__': <class '_frozen_importlib.BuiltinImporter'>, '__spec__': ModuleSpec(name='builtins', loader=<class '_frozen_importlib.BuiltinImporter'>, origin='built-in'), '__build_class__': <built-in function __build_class__>, '__import__': <built-in function __import__>, 'abs': <built-in function abs>, 'all': <built-in function all>, 'any': <built-in function any>, 'ascii': <built-in function ascii>, 'bin': <built-in function bin>, 'breakpoint': <built-in function breakpoint>, 'callable': <built-in function callable>, 'chr': <built-in function chr>, 'compile': <built-in function compile>, 'delattr': <built-in function delattr>, 'dir': <built-in function dir>, 'divmod': <built-in function divmod>, 'eval': <built-in function eval>, 'exec': <built-in function exec>, 'format': <built-in function format>, 'getattr': <built-in function getattr>, 'globals': <built-in function globals>, 'hasattr': <built-in function hasattr>, 'hash': <built-in function hash>, 'hex': <built-in function hex>, 'id': <built-in function id>, 'input': <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x10855eba0>>, 'isinstance': <built-in function isinstance>, 'issubclass': <built-in function issubclass>, 'iter': <built-in function iter>, 'aiter': <built-in function aiter>, 'len': <built-in function len>, 'locals': <built-in function locals>, 'max': <built-in function max>, 'min': <built-in function min>, 'next': <built-in function next>, 'anext': <built-in function anext>, 'oct': <built-in function oct>, 'ord': <built-in function ord>, 'pow': <built-in function pow>, 'print': <built-in function print>, 'repr': <built-in function repr>, 'round': <built-in function round>, 'setattr': <built-in function setattr>, 'sorted': <built-in function sorted>, 'sum': <built-in function sum>, 'vars': <built-in function vars>, 'None': None, 'Ellipsis': Ellipsis, 'NotImplemented': NotImplemented, 'False': False, 'True': True, 'bool': <class 'bool'>, 'memoryview': <class 'memoryview'>, 'bytearray': <class 'bytearray'>, 'bytes': <class 'bytes'>, 'classmethod': <class 'classmethod'>, 'complex': <class 'complex'>, 'dict': <class 'dict'>, 'enumerate': <class 'enumerate'>, 'filter': <class 'filter'>, 'float': <class 'float'>, 'frozenset': <class 'frozenset'>, 'property': <class 'property'>, 'int': <class 'int'>, 'list': <class 'list'>, 'map': <class 'map'>, 'object': <class 'object'>, 'range': <class 'range'>, 'reversed': <class 'reversed'>, 'set': <class 'set'>, 'slice': <class 'slice'>, 'staticmethod': <class 'staticmethod'>, 'str': <class 'str'>, 'super': <class 'super'>, 'tuple': <class 'tuple'>, 'type': <class 'type'>, 'zip': <class 'zip'>, '__debug__': True, 'BaseException': <class 'BaseException'>, 'BaseExceptionGrou ...
#         "args.1": "<class 'scipy.stats._distn_infrastructure.rv_continuous'>"
#     },
#     "events": [],
#     "links": [],
#     "resource": {
#         "attributes": {
#             "telemetry.sdk.language": "python",
#             "telemetry.sdk.name": "opentelemetry",
#             "telemetry.sdk.version": "1.33.0",
#             "service.name": "scipy",
#             "service.namespace": "scientific-python",
#             "deployment.environment": "production",
#             "telemetry.auto.version": "0.54b0"
#         },
#         "schema_url": ""
#     }
# }
# {
#     "name": "scipy.stats._distn_infrastructure.get_distribution_names",
#     "context": {
#         "trace_id": "0xfdb35ae25c435e279a522d9ea85ca9d5",
#         "span_id": "0x103c931ee56f8bac",
#         "trace_state": "[]"
#     },
#     "kind": "SpanKind.INTERNAL",
#     "parent_id": null,
#     "start_time": "2025-05-12T22:18:56.887920Z",
#     "end_time": "2025-05-12T22:18:56.888018Z",
#     "status": {
#         "status_code": "OK"
#     },
#     "attributes": {
#         "num_args": 2,
#         "num_kwargs": 0,
#         "args.0": "[('__name__', 'scipy.stats._discrete_distns'), ('__doc__', None), ('__package__', 'scipy.stats'), ('__loader__', <_frozen_importlib_external.SourceFileLoader object at 0x11a1fae10>), ('__spec__', ModuleSpec(name='scipy.stats._discrete_distns', loader=<_frozen_importlib_external.SourceFileLoader object at 0x11a1fae10>, origin='/Users/guen/repos/guenp/api-tracer/.venv/lib/python3.12/site-packages/scipy/stats/_discrete_distns.py')), ('__file__', '/Users/guen/repos/guenp/api-tracer/.venv/lib/python3.12/site-packages/scipy/stats/_discrete_distns.py'), ('__cached__', '/Users/guen/repos/guenp/api-tracer/.venv/lib/python3.12/site-packages/scipy/stats/__pycache__/_discrete_distns.cpython-312.pyc'), ('__builtins__', {'__name__': 'builtins', '__doc__': \"Built-in functions, types, exceptions, and other objects.\\n\\nThis module provides direct access to all 'built-in'\\nidentifiers of Python; for example, builtins.len is\\nthe full name for the built-in function len().\\n\\nThis module is not normally accessed explicitly by most\\napplications, but can be useful in modules that provide\\nobjects with the same name as a built-in value, but in\\nwhich the built-in of that name is also needed.\", '__package__': '', '__loader__': <class '_frozen_importlib.BuiltinImporter'>, '__spec__': ModuleSpec(name='builtins', loader=<class '_frozen_importlib.BuiltinImporter'>, origin='built-in'), '__build_class__': <built-in function __build_class__>, '__import__': <built-in function __import__>, 'abs': <built-in function abs>, 'all': <built-in function all>, 'any': <built-in function any>, 'ascii': <built-in function ascii>, 'bin': <built-in function bin>, 'breakpoint': <built-in function breakpoint>, 'callable': <built-in function callable>, 'chr': <built-in function chr>, 'compile': <built-in function compile>, 'delattr': <built-in function delattr>, 'dir': <built-in function dir>, 'divmod': <built-in function divmod>, 'eval': <built-in function eval>, 'exec': <built-in function exec>, 'format': <built-in function format>, 'getattr': <built-in function getattr>, 'globals': <built-in function globals>, 'hasattr': <built-in function hasattr>, 'hash': <built-in function hash>, 'hex': <built-in function hex>, 'id': <built-in function id>, 'input': <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x10855eba0>>, 'isinstance': <built-in function isinstance>, 'issubclass': <built-in function issubclass>, 'iter': <built-in function iter>, 'aiter': <built-in function aiter>, 'len': <built-in function len>, 'locals': <built-in function locals>, 'max': <built-in function max>, 'min': <built-in function min>, 'next': <built-in function next>, 'anext': <built-in function anext>, 'oct': <built-in function oct>, 'ord': <built-in function ord>, 'pow': <built-in function pow>, 'print': <built-in function print>, 'repr': <built-in function repr>, 'round': <built-in function round>, 'setattr': <built-in function setattr>, 'sorted': <built-in function sorted>, 'sum': <built-in function sum>, 'vars': <built-in function vars>, 'None': None, 'Ellipsis': Ellipsis, 'NotImplemented': NotImplemented, 'False': False, 'True': True, 'bool': <class 'bool'>, 'memoryview': <class 'memoryview'>, 'bytearray': <class 'bytearray'>, 'bytes': <class 'bytes'>, 'classmethod': <class 'classmethod'>, 'complex': <class 'complex'>, 'dict': <class 'dict'>, 'enumerate': <class 'enumerate'>, 'filter': <class 'filter'>, 'float': <class 'float'>, 'frozenset': <class 'frozenset'>, 'property': <class 'property'>, 'int': <class 'int'>, 'list': <class 'list'>, 'map': <class 'map'>, 'object': <class 'object'>, 'range': <class 'range'>, 'reversed': <class 'reversed'>, 'set': <class 'set'>, 'slice': <class 'slice'>, 'staticmethod': <class 'staticmethod'>, 'str': <class 'str'>, 'super': <class 'super'>, 'tuple': <class 'tuple'>, 'type': <class 'type'>, 'zip': <class 'zip'>, '__debug__': True, 'BaseException': <class 'BaseException'>, 'BaseExceptionGroup': <class ...
#         "args.1": "<class 'scipy.stats._distn_infrastructure.rv_discrete'>"
#     },
#     "events": [],
#     "links": [],
#     "resource": {
#         "attributes": {
#             "telemetry.sdk.language": "python",
#             "telemetry.sdk.name": "opentelemetry",
#             "telemetry.sdk.version": "1.33.0",
#             "service.name": "scipy",
#             "service.namespace": "scientific-python",
#             "deployment.environment": "production",
#             "telemetry.auto.version": "0.54b0"
#         },
#         "schema_url": ""
#     }
# }
# {
#     "name": "scipy.stats._distn_infrastructure.argsreduce",
#     "context": {
#         "trace_id": "0xbafeb8348fccc195e0cca442c913f4b8",
#         "span_id": "0x276439c3514d5fa5",
#         "trace_state": "[]"
#     },
#     "kind": "SpanKind.INTERNAL",
#     "parent_id": "0xb494d548360000fa",
#     "start_time": "2025-05-12T22:18:56.942001Z",
#     "end_time": "2025-05-12T22:18:56.942069Z",
#     "status": {
#         "status_code": "OK"
#     },
#     "attributes": {
#         "num_args": 3,
#         "num_kwargs": 0,
#         "args.0": "1",
#         "args.1": "0.0",
#         "args.2": "0.01"
#     },
#     "events": [],
#     "links": [],
#     "resource": {
#         "attributes": {
#             "telemetry.sdk.language": "python",
#             "telemetry.sdk.name": "opentelemetry",
#             "telemetry.sdk.version": "1.33.0",
#             "service.name": "scipy",
#             "service.namespace": "scientific-python",
#             "deployment.environment": "production",
#             "telemetry.auto.version": "0.54b0"
#         },
#         "schema_url": ""
#     }
# }
# {
#     "name": "scipy.stats._distn_infrastructure.rv_continuous.pdf",
#     "context": {
#         "trace_id": "0xbafeb8348fccc195e0cca442c913f4b8",
#         "span_id": "0xb494d548360000fa",
#         "trace_state": "[]"
#     },
#     "kind": "SpanKind.INTERNAL",
#     "parent_id": null,
#     "start_time": "2025-05-12T22:18:56.941901Z",
#     "end_time": "2025-05-12T22:18:56.942091Z",
#     "status": {
#         "status_code": "OK"
#     },
#     "attributes": {
#         "num_args": 1,
#         "num_kwargs": 3,
#         "args.0": "<scipy.stats._continuous_distns.norm_gen object at 0x11ad1d0d0>",
#         "kwargs.x": 1,
#         "kwargs.loc": 1,
#         "kwargs.scale": 0.01
#     },
#     "events": [],
#     "links": [],
#     "resource": {
#         "attributes": {
#             "telemetry.sdk.language": "python",
#             "telemetry.sdk.name": "opentelemetry",
#             "telemetry.sdk.version": "1.33.0",
#             "service.name": "scipy",
#             "service.namespace": "scientific-python",
#             "deployment.environment": "production",
#             "telemetry.auto.version": "0.54b0"
#         },
#         "schema_url": ""
#     }
# }
# {
#     "name": "scipy.stats._distn_infrastructure.rv_generic.freeze",
#     "context": {
#         "trace_id": "0x5cef0e979c67d2eea61421a6192b4545",
#         "span_id": "0xbd5f889c0d9e50b1",
#         "trace_state": "[]"
#     },
#     "kind": "SpanKind.INTERNAL",
#     "parent_id": null,
#     "start_time": "2025-05-12T22:18:56.942126Z",
#     "end_time": "2025-05-12T22:18:56.942376Z",
#     "status": {
#         "status_code": "OK"
#     },
#     "attributes": {
#         "num_args": 1,
#         "num_kwargs": 2,
#         "args.0": "<scipy.stats._continuous_distns.norm_gen object at 0x11ad1d0d0>",
#         "kwargs.loc": 1,
#         "kwargs.scale": 0.02
#     },
#     "events": [],
#     "links": [],
#     "resource": {
#         "attributes": {
#             "telemetry.sdk.language": "python",
#             "telemetry.sdk.name": "opentelemetry",
#             "telemetry.sdk.version": "1.33.0",
#             "service.name": "scipy",
#             "service.namespace": "scientific-python",
#             "deployment.environment": "production",
#             "telemetry.auto.version": "0.54b0"
#         },
#         "schema_url": ""
#     }
# }
# {
#     "name": "scipy.stats._distn_infrastructure.argsreduce",
#     "context": {
#         "trace_id": "0xcbe4a828f1d559c23ca377df589c0fa4",
#         "span_id": "0x592e3c8f4a6e7ed9",
#         "trace_state": "[]"
#     },
#     "kind": "SpanKind.INTERNAL",
#     "parent_id": "0xfbe23c3d7a2efe13",
#     "start_time": "2025-05-12T22:18:56.942453Z",
#     "end_time": "2025-05-12T22:18:56.942479Z",
#     "status": {
#         "status_code": "OK"
#     },
#     "attributes": {
#         "num_args": 3,
#         "num_kwargs": 0,
#         "args.0": "1",
#         "args.1": "0.0",
#         "args.2": "0.02"
#     },
#     "events": [],
#     "links": [],
#     "resource": {
#         "attributes": {
#             "telemetry.sdk.language": "python",
#             "telemetry.sdk.name": "opentelemetry",
#             "telemetry.sdk.version": "1.33.0",
#             "service.name": "scipy",
#             "service.namespace": "scientific-python",
#             "deployment.environment": "production",
#             "telemetry.auto.version": "0.54b0"
#         },
#         "schema_url": ""
#     }
# }
# {
#     "name": "scipy.stats._distn_infrastructure.rv_continuous.pdf",
#     "context": {
#         "trace_id": "0xcbe4a828f1d559c23ca377df589c0fa4",
#         "span_id": "0xfbe23c3d7a2efe13",
#         "trace_state": "[]"
#     },
#     "kind": "SpanKind.INTERNAL",
#     "parent_id": "0x3f98921699286878",
#     "start_time": "2025-05-12T22:18:56.942419Z",
#     "end_time": "2025-05-12T22:18:56.942488Z",
#     "status": {
#         "status_code": "OK"
#     },
#     "attributes": {
#         "num_args": 2,
#         "num_kwargs": 2,
#         "args.0": "<scipy.stats._continuous_distns.norm_gen object at 0x11b7296a0>",
#         "args.1": 1,
#         "kwargs.loc": 1,
#         "kwargs.scale": 0.02
#     },
#     "events": [],
#     "links": [],
#     "resource": {
#         "attributes": {
#             "telemetry.sdk.language": "python",
#             "telemetry.sdk.name": "opentelemetry",
#             "telemetry.sdk.version": "1.33.0",
#             "service.name": "scipy",
#             "service.namespace": "scientific-python",
#             "deployment.environment": "production",
#             "telemetry.auto.version": "0.54b0"
#         },
#         "schema_url": ""
#     }
# }
# {
#     "name": "scipy.stats._distn_infrastructure.rv_continuous_frozen.pdf",
#     "context": {
#         "trace_id": "0xcbe4a828f1d559c23ca377df589c0fa4",
#         "span_id": "0x3f98921699286878",
#         "trace_state": "[]"
#     },
#     "kind": "SpanKind.INTERNAL",
#     "parent_id": null,
#     "start_time": "2025-05-12T22:18:56.942389Z",
#     "end_time": "2025-05-12T22:18:56.942490Z",
#     "status": {
#         "status_code": "OK"
#     },
#     "attributes": {
#         "num_args": 2,
#         "num_kwargs": 0,
#         "args.0": "<scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x11b729640>",
#         "args.1": 1
#     },
#     "events": [],
#     "links": [],
#     "resource": {
#         "attributes": {
#             "telemetry.sdk.language": "python",
#             "telemetry.sdk.name": "opentelemetry",
#             "telemetry.sdk.version": "1.33.0",
#             "service.name": "scipy",
#             "service.namespace": "scientific-python",
#             "deployment.environment": "production",
#             "telemetry.auto.version": "0.54b0"
#         },
#         "schema_url": ""
#     }
# }
# {
#     "name": "scipy.stats._correlation._chatterjeexi_iv",
#     "context": {
#         "trace_id": "0x04bbd885940f80e42aabfb1bf5ed04f5",
#         "span_id": "0x3bedc2e5213e3485",
#         "trace_state": "[]"
#     },
#     "kind": "SpanKind.INTERNAL",
#     "parent_id": "0x3284a483d2dc6d0b",
#     "start_time": "2025-05-12T22:18:56.942675Z",
#     "end_time": "2025-05-12T22:18:56.942685Z",
#     "status": {
#         "status_code": "OK"
#     },
#     "attributes": {
#         "num_args": 2,
#         "num_kwargs": 0,
#         "args.0": false,
#         "args.1": "asymptotic"
#     },
#     "events": [],
#     "links": [],
#     "resource": {
#         "attributes": {
#             "telemetry.sdk.language": "python",
#             "telemetry.sdk.name": "opentelemetry",
#             "telemetry.sdk.version": "1.33.0",
#             "service.name": "scipy",
#             "service.namespace": "scientific-python",
#             "deployment.environment": "production",
#             "telemetry.auto.version": "0.54b0"
#         },
#         "schema_url": ""
#     }
# }
# {
#     "name": "scipy.stats._correlation._xi_statistic",
#     "context": {
#         "trace_id": "0x04bbd885940f80e42aabfb1bf5ed04f5",
#         "span_id": "0xd02f61a0a85e77d4",
#         "trace_state": "[]"
#     },
#     "kind": "SpanKind.INTERNAL",
#     "parent_id": "0x3284a483d2dc6d0b",
#     "start_time": "2025-05-12T22:18:56.942694Z",
#     "end_time": "2025-05-12T22:18:56.942919Z",
#     "status": {
#         "status_code": "OK"
#     },
#     "attributes": {
#         "num_args": 3,
#         "num_kwargs": 0,
#         "args.0": "[1 2 3 4]",
#         "args.1": "[1.1 2.2 3.3 4.4]",
#         "args.2": false
#     },
#     "events": [],
#     "links": [],
#     "resource": {
#         "attributes": {
#             "telemetry.sdk.language": "python",
#             "telemetry.sdk.name": "opentelemetry",
#             "telemetry.sdk.version": "1.33.0",
#             "service.name": "scipy",
#             "service.namespace": "scientific-python",
#             "deployment.environment": "production",
#             "telemetry.auto.version": "0.54b0"
#         },
#         "schema_url": ""
#     }
# }
# {
#     "name": "scipy.stats._correlation._xi_std",
#     "context": {
#         "trace_id": "0x04bbd885940f80e42aabfb1bf5ed04f5",
#         "span_id": "0xb8f0c17b4aaf4cd3",
#         "trace_state": "[]"
#     },
#     "kind": "SpanKind.INTERNAL",
#     "parent_id": "0x3284a483d2dc6d0b",
#     "start_time": "2025-05-12T22:18:56.942931Z",
#     "end_time": "2025-05-12T22:18:56.943017Z",
#     "status": {
#         "status_code": "OK"
#     },
#     "attributes": {
#         "num_args": 3,
#         "num_kwargs": 0,
#         "args.0": "[1 2 3 4]",
#         "args.1": "[4 3 2 1]",
#         "args.2": false
#     },
#     "events": [],
#     "links": [],
#     "resource": {
#         "attributes": {
#             "telemetry.sdk.language": "python",
#             "telemetry.sdk.name": "opentelemetry",
#             "telemetry.sdk.version": "1.33.0",
#             "service.name": "scipy",
#             "service.namespace": "scientific-python",
#             "deployment.environment": "production",
#             "telemetry.auto.version": "0.54b0"
#         },
#         "schema_url": ""
#     }
# }
# {
#     "name": "scipy.stats._correlation.chatterjeexi",
#     "context": {
#         "trace_id": "0x04bbd885940f80e42aabfb1bf5ed04f5",
#         "span_id": "0x3284a483d2dc6d0b",
#         "trace_state": "[]"
#     },
#     "kind": "SpanKind.INTERNAL",
#     "parent_id": null,
#     "start_time": "2025-05-12T22:18:56.942520Z",
#     "end_time": "2025-05-12T22:18:56.943036Z",
#     "status": {
#         "status_code": "OK"
#     },
#     "attributes": {
#         "num_args": 2,
#         "num_kwargs": 0,
#         "args.0": [
#             1,
#             2,
#             3,
#             4
#         ],
#         "args.1": [
#             1.1,
#             2.2,
#             3.3,
#             4.4
#         ]
#     },
#     "events": [],
#     "links": [],
#     "resource": {
#         "attributes": {
#             "telemetry.sdk.language": "python",
#             "telemetry.sdk.name": "opentelemetry",
#             "telemetry.sdk.version": "1.33.0",
#             "service.name": "scipy",
#             "service.namespace": "scientific-python",
#             "deployment.environment": "production",
#             "telemetry.auto.version": "0.54b0"
#         },
#         "schema_url": ""
#     }
# }

# %%
from scipy import stats

stats.norm.pdf(x=1, loc=1, scale=0.01)
stats.norm(loc=1, scale=0.02).pdf(1)

stats.chatterjeexi([1, 2, 3, 4], [1.1, 2.2, 3.3, 4.4])
# Out:
# SignificanceResult(statistic=np.float64(0.4), pvalue=np.float64(0.13362874657719392))
